# %% [markdown]
# <a href="https://colab.research.google.com/github/bsnehas/-vsproject/blob/master/covid_19_project1_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
covid=pd.read_csv('/content/covid19.csv')

# %%
covid.head()
# Out:
#   Country/Region      Continent  Population  TotalCases  NewCases  \
# 0            USA  North America   331198130     5032179       NaN
# 1         Brazil  South America   212710692     2917562       NaN
# 2          India           Asia  1381344997     2025409       NaN
# 3         Russia         Europe   145940924      871894       NaN
# 4   South Africa         Africa    59381566      538184       NaN
#
#    TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# 0       162804        NaN       2576668.0           NaN    2292707.0
# 1        98644        NaN       2047660.0           NaN     771258.0
# 2        41638        NaN       1377384.0           NaN     606387.0
# 3        14606        NaN        676357.0           NaN     180931.0
# 4         9604        NaN        387316.0           NaN     141264.0
#
#    Serious,Critical      WHO Region
# 0           18296.0        Americas
# 1            8318.0        Americas
# 2            8944.0  South-EastAsia
# ...

# %%
covid.shape
# Out:
# (49, 12)

# %%
covid.columns
# Out:
# Index(['Country/Region', 'Continent', 'Population', 'TotalCases', 'NewCases',
#        'TotalDeaths', 'NewDeaths', 'TotalRecovered', 'NewRecovered',
#        'ActiveCases', 'Serious,Critical', 'WHO Region'],
#       dtype='object')

# %%
covid.describe(include="O")
# Out:
#        Country/Region Continent WHO Region
# count              49        49         49
# unique             49         5          6
# top               USA      Asia     Europe
# freq                1        18         17

# %%
covid.isna().any() #check if col have null values
# Out:
# Country/Region      False
# Continent           False
# Population          False
# TotalCases          False
# NewCases             True
# TotalDeaths         False
# NewDeaths            True
# TotalRecovered       True
# NewRecovered         True
# ActiveCases          True
# Serious,Critical     True
# WHO Region          False
# dtype: bool

# %%
covid.isna().sum()
# Out:
# Country/Region       0
# Continent            0
# Population           0
# TotalCases           0
# NewCases            47
# TotalDeaths          0
# NewDeaths           47
# TotalRecovered       4
# NewRecovered        47
# ActiveCases          4
# Serious,Critical     5
# WHO Region           0
# dtype: int64

# %%
india_case=covid[covid['Country/Region']=='India']

# %%
india_case.head()
# Out:
#   Country/Region Continent  Population  TotalCases  NewCases  TotalDeaths  \
# 2          India      Asia  1381344997     2025409       NaN        41638
#
#    NewDeaths  TotalRecovered  NewRecovered  ActiveCases  Serious,Critical  \
# 2        NaN       1377384.0           NaN     606387.0            8944.0
#
#        WHO Region
# 2  South-EastAsia

# %%
india_case.tail()
# Out:
#   Country/Region Continent  Population  TotalCases  NewCases  TotalDeaths  \
# 2          India      Asia  1381344997     2025409       NaN        41638
#
#    NewDeaths  TotalRecovered  NewRecovered  ActiveCases  Serious,Critical  \
# 2        NaN       1377384.0           NaN     606387.0            8944.0
#
#        WHO Region
# 2  South-EastAsia
